# %% [markdown]
# <h1 style="color:red">Battle Of Neighbourhoods</h1>

# %% [markdown]
# ## <span style="color:red">Table of contents</span>
# * [Introduction](#introduction)
# * [Project Description](#data)
# * [Data](#data)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# <h1 style='color:red'>Introduction</h1>
# Bangalore is called as The Silicon Valley of India because of the large number of information technology companies located in the city which contributed 33% of India's ₹1,442 billion (US$21 billion) IT exports.In recent decades, the city has witnessed rapid growth in population and urbanised area. While Central Bangalore is the commercial heart of the city, Eastern and South-Eastern Bangalore areas are major hubs for IT and financial companies. Southern and Western parts of the city are mainly residential areas. The neighbourhoods in the Northern and North-Eastern regions are both industrial and residential.

# %% [markdown]
# <h1 style='color:red'>Project Description</h1>
# This project demonstrates an analysis of venues in Bangalore(India) using heterogeneous data sources and data science methods. This requires the extraction, load, transformation and analysis of all data sources contained in the following notebook.<br><br>
# Since Bangalore is cosmopolitan there are lots of venues in Bangalore, so we will try to segment venues into <b>Clusters(based on geographical location)</b>. We are also particularly interested in people who visiting Bangalore and want to explore the city. Futhermore We would also prefer popular locations as there will also be people on a <b>short-trip.</b>
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.
#
# ### Target Audience
# <ul>
# <li>In this project we will try to find an optimal location for a restaurant. Specifically, this report will be targeted to         traveller interested in exploring <b>different Venue</b> in <b>Bangalore</b>, India.</li>
# </ul>

# %% [markdown]
# <h1 style="color:red">Data</h1>
# The data is fetched from following resources:
# <ul>
# <li>Four Square API</li>
# </ul>

# %% [markdown]
# <h1 style='color:red'>Analysis</h1>

# %% [markdown]
# ### Importing the Libraries

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.geocoders import Nominatim
from sklearn.cluster import KMeans

# %%
# co-ordinates of Bangalore
latitude = '12.9716'
longitude = '77.5946'

# %% [markdown]
# ### Four Square API

# %%
CLIENT_ID = '00IVVZKELM2KPVHLPFMUXMY5QZHDGZPX5SSB4HURZJ2KKKMT' # your Foursquare ID
CLIENT_SECRET = 'ZZQNWZTOEZSYA2MXCQBU12OIELDNEQQH3YKKJBDNIWYZ0ZF4' # your Foursquare Secret
VERSION = '20190605' # Foursquare API version

# %% [markdown]
# ### Getting Recommended Venues
# <b><i><u>https://api.foursquare.com/v2/venues/explore?</u></i></b>  API is used to get the Popular places of Bangalore

# %%
LIMIT = 100
radius=500
def getRecommended(latitude, longitude):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude, 
            longitude, 
            radius,
#             category,
            LIMIT)
    results = requests.get(url).json()["response"]["groups"][0]['items']
    Recommended_list = []
    for v in results:
            Recommended_list.append([( 
            v['venue']['name'],
            v['venue']['location']['formattedAddress'][0],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name'])])
            
        
    Recommended = pd.DataFrame([item for venue in Recommended_list for item in venue])
    Recommended.columns = [ 
                  'VenueName', 
                   'Address',
                  'Latitude', 
                  'Longitude', 
                  'SubCategory']
    return(Recommended)
recommended = getRecommended(latitude,longitude)

# %%
recommended.head()
# Out:
#                      VenueName  \
# 0  JW Marriott Hotel Bengaluru
# 1                      UB City
# 2                      Toscano
# 3                  J W Kitchen
# 4                        Shiro
#
#                                              Address   Latitude  Longitude  \
# 0                            24/1 Vittal Mallya Road  12.972362  77.595051
# 1                                at Vittal Mallya Rd  12.971709  77.595905
# 2  UB City Level 2 Concorde Block (24 Vittal Mall...  12.971980  77.596066
# 3                 Near U B City (Vittal Mallya Road)  12.972410  77.594592
# 4  3rd Flr., UB City, Vittal Mallya Rd. (Lavelle ...  12.971900  77.596236
#
#            SubCategory
# 0                Hotel
# 1        Shopping Mall
# 2   Italian Restaurant
# 3     Asian Restaurant
# 4  Japanese Restaurant

# %%
recommended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
# VenueName      54 non-null object
# Address        54 non-null object
# Latitude       54 non-null float64
# Longitude      54 non-null float64
# SubCategory    54 non-null object
# dtypes: float64(2), object(3)
# memory usage: 1.5+ KB

# %% [markdown]
# ### Getting All Venues
# <b><i><u>https://api.foursquare.com/v2/venues/explore?</u></i></b>  API is used to get the all venues of Bangalore.

# %%
LIMIT = 500
radius=1000
def getVenues(latitude, longitude):
    url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude, 
            longitude, 
            radius,
#             category,
            LIMIT)
    results = requests.get(url).json()["response"]["venues"]
    Venue_list = []
    for v in results:
            if v['categories'] != []:
                Venue_list.append([( 
                v['name'],
                v['location']['formattedAddress'][0],
                v['location']['lat'], 
                v['location']['lng'],
                v['categories'][0]['name'])])
    Venue = pd.DataFrame([item for venue in Venue_list for item in venue])
    Venue.columns = [ 
                  'VenueName', 
                    'Address',
                  'Latitude', 
                  'Longitude',
                  'SubCategory']
    return(Venue)
venues = getVenues(latitude,longitude)

# %%
venues
# Out:
#                                        VenueName  \
# 0                              Coffee Day Square
# 1                             Cafe Coffee Day HQ
# 2                   JW Marriott Executive Lounge
# 3                    JW Marriott Hotel Bengaluru
# 4                             BBC by JW Marriott
# 5                      Kanteerava Indoor Stadium
# 6                                      Bangalore
# 7                                      INFOSYS 3
# 8                                           Alba
# 9                                    Cubbon Park
# 10                       Sree Kanteerava Stadium
# 11                                          Tumi
# 12                                            3M
# 13                                       UB City
# 14                                     J W Salon
# 15                                      HDFC Ltd
# 16                                          Fava
# 17                DIESEL - For Successful Living
# 18                                     Café Noir
# 19                                         Shiro
# 20                                     HDFC Bank
# 21                                 Spice Terrace
# 22                                  Diesel Store
# 23                                 Louis Vuitton
# 24                                      Burberry
# 25                                     UB Towers
# 26                                  Michael Kors
# 27                                       Sanchez
# 28                                           JLL
# 29                                       Amadora
# ..                                           ...
# 157                                   Yogurt Hub
# 158                                   Good Earth
# 159                                     Sancho's
# 160                             Turquoise & Gold
# 161                                        E & Y
# 162                                       amande
# 163                                  Hivos India
# 164                          Amruthalooka M.R.P.
# 165                               Etihad Airways
# 166                                      Leb Mex
# 167                                       Llardo
# 168                    Euromonitor International
# 169  Tribune Digital Ventures SDC India Pvt Ltd.
# 170                           Nilgiris Cake Show
# 171                    Nandhini Whitefield Hotel
# 172                                      Zaffran
# 173                                      Shimmer
# 174                         GTV, Cafe Coffee Day
# 175                               Bottega Veneta
# 176                              Shanthala Nagar
# 177                               Home Gymnasium
# 178                           Shining Consulting
# 179                                       Samsar
# 180                         LobbyLounge@Oakwoods
# 181                                 Elements Spa
# 182                    Vittal Mallya Rd Bus Stop
# 183                     Artin Dynamics Bangalore
# 184                                         Ozaa
# 182                                   Vittal Mallya Rd  12.969631  77.594730
# 183                  Axis Bank Building (Sanjay Nagar)  12.971397  77.595288
# 184  Oakwood Premier Prestige,UB City,Vittal Mallya...  12.972159  77.596263
# 185                                          Bangalore  12.971566  77.596543
# 186                                              India  12.972326  77.596199
#
#                   SubCategory
# 0                 Coffee Shop
# 1                      Office
# 2                      Lounge
# 3                       Hotel
# 4                        Café
# 5                     Stadium
# 6                        City
# 7                      Office
# 8          Italian Restaurant
# 9                        Park
# 10                    Stadium
# 11          Accessories Store
# 12                     Office
# 13              Shopping Mall
# 14         Salon / Barbershop
# 15                       Bank
# 16   Mediterranean Restaurant
# 17             Clothing Store
# 18          French Restaurant
# 19        Japanese Restaurant
# 20                       Bank
# 21                     Lounge
# 22             Clothing Store
# 23                   Boutique
# 24             Clothing Store
# 25                     Office
# 26          Accessories Store
# 27         Mexican Restaurant
# 28                     Office
# 29             Ice Cream Shop
# ..                        ...
# 157        Frozen Yogurt Shop
# 158       Arts & Crafts Store
# 159        Mexican Restaurant
# 160             Women's Store
# 161                    Office
# 162         French Restaurant
# 163                    Office
# 164                Beer Store
# 165             Travel Agency
# 166        Mexican Restaurant
# 167       Arts & Crafts Store
# 168           Campaign Office
# 169              Tech Startup
# 170     General Entertainment
# 171         Indian Restaurant
# 172         Indian Restaurant
# 173            Clothing Store
# 174                    Office
# 175       Leather Goods Store
# 176              Neighborhood
# 177                       Gym
# 178                    Office
# 179            Clothing Store
# 180                 Piano Bar
# 181                       Spa
# 182                  Bus Line
# 183              Tech Startup
# 184                     Diner
# 185                    Office
# 186        Salon / Barbershop
#
# [187 rows x 5 columns]

# %% [markdown]
# ### Categorising data into following Parent Categories

# %%
def giveCategory(self):
    self.replace('Café','Cafe')
    if 'Restaurant' in  self:
        return 'Restaurant'
    elif self == 'Coffee Shop':
        return 'Cafe'
    elif self == 'Café':
        return 'Cafe'
    else:
        return self
recommended['Category'] = recommended['SubCategory'].apply(giveCategory)
venues['Category'] = venues['SubCategory'].apply(giveCategory)

# %% [markdown]
# ### Clustering the data based on their Latitude and Longitude

# %% [markdown]
# #### Recommended

# %%
kclusters = 5

cluster = recommended[['Latitude','Longitude']]
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(cluster)
recommended['Cluster Labels'] = kmeans.labels_
recommended.head()
# Out:
#                      VenueName  \
# 0  JW Marriott Hotel Bengaluru
# 1                      UB City
# 2                      Toscano
# 3                  J W Kitchen
# 4                        Shiro
#
#                                              Address   Latitude  Longitude  \
# 0                            24/1 Vittal Mallya Road  12.972362  77.595051
# 1                                at Vittal Mallya Rd  12.971709  77.595905
# 2  UB City Level 2 Concorde Block (24 Vittal Mall...  12.971980  77.596066
# 3                 Near U B City (Vittal Mallya Road)  12.972410  77.594592
# 4  3rd Flr., UB City, Vittal Mallya Rd. (Lavelle ...  12.971900  77.596236
#
#            SubCategory       Category  Cluster Labels
# 0                Hotel          Hotel               2
# 1        Shopping Mall  Shopping Mall               4
# 2   Italian Restaurant     Restaurant               4
# 3     Asian Restaurant     Restaurant               2
# 4  Japanese Restaurant     Restaurant               4

# %% [markdown]
# #### Venues

# %%
kclusters = 5
cluster = venues[['Latitude','Longitude']]
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(cluster)
venues['Cluster Labels'] = kmeans.labels_
venues.head()
# Out:
#                       VenueName                                     Address  \
# 0             Coffee Day Square          #23/2, Near UB City (Near UB City)
# 1            Cafe Coffee Day HQ  23/2,Coffee Day Square,Vittal Mallaya Road
# 2  JW Marriott Executive Lounge                                       India
# 3   JW Marriott Hotel Bengaluru                     24/1 Vittal Mallya Road
# 4            BBC by JW Marriott                                   Bangalore
#
#     Latitude  Longitude  SubCategory Category  Cluster Labels
# 0  12.971671  77.594132  Coffee Shop     Cafe               0
# 1  12.971827  77.594242       Office   Office               0
# 2  12.972120  77.594804       Lounge   Lounge               0
# 3  12.972362  77.595051        Hotel    Hotel               0
# 4  12.971847  77.595088         Café     Cafe               0

# %%
plt.figure(1,figsize=(15,4))

plt.subplots_adjust(hspace=0.5, wspace=0.7)

a = plt.subplot(121)
a.set_title('Recommended')
sns.countplot(recommended['Cluster Labels'])

a = plt.subplot(122)
a.set_title('Venues')
sns.countplot(venues['Cluster Labels'])

plt.show()

# %% [markdown]
#  _We can see that most of the Recommended Lies under **cluster '2'** whereas **Cluster '1'** contains maximum number of venues_

# %% [markdown]
# ### Segmenting Recommended Data
# Below given is the analysis for the Individuals who have a short trip to Bangalore. So the popular places are suggested.<br>
# Places have been segmented on following 2 parameters:
# #### On basis of Categories
# ##### Categories are as mentioned below
# <ul>
#     <li>Restaurant</li>
#     <li>Clothing Stores</li>
#     <li>Cafes</li>
#     <li>Lounge</li>
# </ul>

# %%
recommended_restaurant = recommended[recommended['Category'] == 'Restaurant'].reset_index(drop = True)
recommended_cafe = recommended[recommended['Category'] == 'Cafe'].reset_index(drop = True)
recommended_hotel = recommended[recommended['Category'] == 'Hotel'].reset_index(drop = True)
recommended_lounge = recommended[recommended['Category'] == 'Lounge'].reset_index(drop = True)
recommended_clothing = recommended[recommended['Category'] == 'Clothing Store'].reset_index(drop = True)

# %% [markdown]
# ### Visualization of Category distribution across different Clusters

# %%
plt.figure(1,figsize=(20,8))

plt.subplots_adjust(hspace=0.5, wspace=0.7)

a = plt.subplot(231)
a.set_title('Restaurant')
sns.countplot(recommended_restaurant['Cluster Labels'])

a = plt.subplot(232)
a.set_title('Cafe')
sns.countplot(recommended_cafe['Cluster Labels'])

a = plt.subplot(233)
a.set_title('Hotel')
sns.countplot(recommended_hotel['Cluster Labels'])

a = plt.subplot(234)
a.set_title('Lounge')
sns.countplot(recommended_lounge['Cluster Labels'])

a = plt.subplot(235)
a.set_title('Clothing')
sns.countplot(recommended_clothing['Cluster Labels'])


plt.show()

# %% [markdown]
# Clearly, we can say that **Cluster 2** have more Restaurant, whereas other venues are almost equally distributed.

# %%
recommended_restaurant
# Out:
#                             VenueName  \
# 0                             Toscano
# 1                         J W Kitchen
# 2                               Shiro
# 3                           Café Noir
# 4                                Alba
# 5                             Sunny's
# 6                                Fava
# 7              Soda Bottle Openerwala
# 8                            Rasovara
# 9                   Konark Kanteerava
# 10                           Sancho's
# 11                        Le Cristaal
# 12  The Glass House - Deli Bistro Bar
# 13                  The Tower Kitchen
# 14                            Sanchos
# 1  Oakwood Premier Prestige Bangalore  Vittal Mallya Road, UB City  12.972002
# 2          ibis Bangalore City Centre                        India  12.967347
#
#    Longitude SubCategory Category  Cluster Labels
# 0  77.595051       Hotel    Hotel               2
# 1  77.596056       Hotel    Hotel               4
# 2  77.593958       Hotel    Hotel               3

# %%
recommended_lounge
# Out:
#                       VenueName  \
# 0                         Skyye
# 1                 Spice Terrace
# 2  JW Marriott Executive Lounge
#
#                                              Address   Latitude  Longitude  \
# 0  Uber Level, 16th Flr., UB City, Vittal Mallya ...  12.971646  77.596242
# 1                                          JW Mariot  12.972254  77.595200
# 2                                              India  12.972120  77.594804
#
#   SubCategory Category  Cluster Labels
# 0      Lounge   Lounge               4
# 1      Lounge   Lounge               2
# 2      Lounge   Lounge               2

# %%
recommended_clothing
# Out:
#                         VenueName  \
# 0                    Diesel Store
# 1  DIESEL - For Successful Living
#
#                                              Address   Latitude  Longitude  \
# 0  Shop 1/1, Ground Floor, Concorde Towers, UB Ci...  12.971762  77.595947
# 1  1/1, Ground Flr, Concorde Towers, UB City (at ...  12.971846  77.595647
#
#       SubCategory        Category  Cluster Labels
# 0  Clothing Store  Clothing Store               4
# 1  Clothing Store  Clothing Store               4

# %% [markdown]
# #### On basis of Clusters</h4>

# %%
recommended_Cluster_0 = recommended[recommended['Cluster Labels'] == 0].reset_index(drop = True)
recommended_Cluster_1 = recommended[recommended['Cluster Labels'] == 1].reset_index(drop = True)
recommended_Cluster_2 = recommended[recommended['Cluster Labels'] == 2].reset_index(drop = True)
recommended_Cluster_3 = recommended[recommended['Cluster Labels'] == 3].reset_index(drop = True)
recommended_Cluster_4 = recommended[recommended['Cluster Labels'] == 4].reset_index(drop = True)

# %%
plt.figure(1,figsize=(20,10))

plt.subplots_adjust(hspace=0.9, wspace=0.7)

a = plt.subplot(231)
a.set_title('Cluster_0')
sns.countplot(recommended_Cluster_0['Category'])
plt.xticks(rotation=90)

a = plt.subplot(232)
a.set_title('Cluster_1')
sns.countplot(recommended_Cluster_1['Category'])
plt.xticks(rotation=90)

a = plt.subplot(233)
a.set_title('Cluster_2')
sns.countplot(recommended_Cluster_2['Category'])
plt.xticks(rotation=90)

a = plt.subplot(234)
a.set_title('Cluster_3')
sns.countplot(recommended_Cluster_3['Category'])
plt.xticks(rotation=90)

a = plt.subplot(235)
a.set_title('Cluster_4')
sns.countplot(recommended_Cluster_4['Category'])

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Cluster 2** has maximum venues followed by **Cluster 1**.

# %%
recommended_Cluster_0
# Out:
#                                           VenueName  \
# 0                            Venkatappa Art Gallery
# 1  Visvesvaraya Industrial and Technological Museum
# 2                              KSLTA Tennis stadium
#
#                       Address   Latitude  Longitude     SubCategory  \
# 0               Kasturba Road  12.974575  77.595792     Art Gallery
# 1               Kasturba Road  12.974884  77.596526  Science Museum
# 2  Kasturba Rd, Shivaji Nagar  12.975094  77.594439  Tennis Stadium
#
#          Category  Cluster Labels
# 0     Art Gallery               0
# 1  Science Museum               0
# 2  Tennis Stadium               0

# %%
recommended_Cluster_1
# Out:
#                             VenueName  \
# 0                    Smoke House Deli
# 1                      The Biere Club
# 2          Good Earth - Bunglow Store
# 5               Cupcake Shop         Cupcake Shop               4
# 6             Clothing Store       Clothing Store               4
# 7                   Boutique             Boutique               4
# 8   Mediterranean Restaurant           Restaurant               4
# 9      Rajasthani Restaurant           Restaurant               4
# 10       Arts & Crafts Store  Arts & Crafts Store               4
# 11        Mexican Restaurant           Restaurant               4
# 12                     Hotel                Hotel               4
# 13                    Bistro               Bistro               4
# 14         Electronics Store    Electronics Store               4
# 15        Italian Restaurant           Restaurant               4
# 16              Concert Hall         Concert Hall               4
# 17        Mexican Restaurant           Restaurant               4
# 18        Italian Restaurant           Restaurant               4
# 19      Cantonese Restaurant           Restaurant               4
# 20         Electronics Store    Electronics Store               4
# 21          Asian Restaurant           Restaurant               4
# 22            Clothing Store       Clothing Store               4

# %% [markdown]
# ## Therefore we conclude that the tourist on a short-trip should visit locations segmented under Cluster 2 for the best experience.

# %% [markdown]
# ### Segmenting Venues Data
# This section displays analysis for people who have a considerable amount of time in Bangalore so as to explore Bangalore to a <br>much grater extent.

# %% [markdown]
# #### On basis of Categories</h4>

# %%
restaurant = venues[venues['Category'] == 'Restaurant'].reset_index(drop = True)
cafe = venues[venues['Category'] == 'Cafe'].reset_index(drop = True)
hotel = venues[venues['Category'] == 'Hotel'].reset_index(drop = True)
lounge = venues[venues['Category'] == 'Lounge'].reset_index(drop = True)
clothing = venues[venues['Category'] == 'Clothing Store'].reset_index(drop = True)

# %%
plt.figure(1,figsize=(20,8))

plt.subplots_adjust(hspace=0.5, wspace=0.7)

a = plt.subplot(231)
a.set_title('Restaurant')
sns.countplot(restaurant['Cluster Labels'])

a = plt.subplot(232)
a.set_title('Cafe')
sns.countplot(cafe['Cluster Labels'])

a = plt.subplot(233)
a.set_title('Hotel')
sns.countplot(hotel['Cluster Labels'])

a = plt.subplot(234)
a.set_title('Lounge')
sns.countplot(lounge['Cluster Labels'])

a = plt.subplot(235)
a.set_title('Clothing')
sns.countplot(clothing['Cluster Labels'])


plt.show()

# %% [markdown]
# **Cluster 1** has maximum number of Restaurants although cafe are situated more in **cluster 0**.

# %%
restaurant
# Out:
#                     VenueName  \
# 0                        Alba
# 1                        Fava
# 2                   Café Noir
# 3                       Shiro
# 4                     Sanchez
# 5                 J W Kitchen
# 6                     Toscano
# 7                     Sanchos
# 8                    Rasovara
# 9                    Sriracha
# 10            Toscana Ub City
# 11                Cafe Mangii
# 12                Café Mangii
# 13                  Sing Kong
# 14                     konark
# 15                   Sancho's
# 16          The Tower Kitchen
# 17                   Sancho's
# 18                     amande
# 19                    Leb Mex
# 20  Nandhini Whitefield Hotel
# 21                    Zaffran
#
#                                               Address   Latitude  Longitude  \
# 0          JW Marriott Bengaluru (Vittal Mallya Road)  12.972541  77.594594
# 1   #203, 2nd Flr, The Collection, UB City (Vittal...  12.972286  77.595966
# 2   2nd Floor, UB City, Vittal Mallya Road, Near L...  12.971995  77.596001
# 3   3rd Flr., UB City, Vittal Mallya Rd. (Lavelle ...  12.971900  77.596236
# 4                                           Bangalore  12.972018  77.596025
# 5                  Near U B City (Vittal Mallya Road)  12.972410  77.594592
# 6   UB City Level 2 Concorde Block (24 Vittal Mall...  12.971980  77.596066
#
#   SubCategory Category  Cluster Labels
# 0      Lounge   Lounge               0
# 1      Lounge   Lounge               0
# 2      Lounge   Lounge               1

# %%
clothing
# Out:
#                         VenueName  \
# 0  DIESEL - For Successful Living
# 1                    Diesel Store
# 2                        Burberry
# 3       United Colors of Benetton
# 4                     Zegna Store
# 5                            ETRO
# 6                         Versace
# 7                         Shimmer
# 8                          Samsar
#
#                                              Address   Latitude  Longitude  \
# 0  1/1, Ground Flr, Concorde Towers, UB City (at ...  12.971846  77.595647
# 1  Shop 1/1, Ground Floor, Concorde Towers, UB Ci...  12.971762  77.595947
# 2  Canberra Block, Vittal Mallya Road (Canberra B...  12.971727  77.596144
# 3                          16/3, Commisseriate Road,  12.971599  77.594562
# 4  The Collection, Ground Floor (UB City, Vittal ...  12.971884  77.595343
# 5               UB City, Ground Floor (Lavelle Road)  12.971890  77.595837
# 6                                              India  12.971678  77.596089
# 7                                            UB City  12.972003  77.596100
# 8                                          Bangalore  12.971599  77.594563
#
#       SubCategory        Category  Cluster Labels
# 0  Clothing Store  Clothing Store               1
# 1  Clothing Store  Clothing Store               1
# 2  Clothing Store  Clothing Store               1
# 3  Clothing Store  Clothing Store               0
# 4  Clothing Store  Clothing Store               1
# 5  Clothing Store  Clothing Store               1
# 6  Clothing Store  Clothing Store               1
# 7  Clothing Store  Clothing Store               1
# 8  Clothing Store  Clothing Store               0

# %% [markdown]
# #### On basis of Clusters</h4>

# %%
Cluster_0 = venues[venues['Cluster Labels'] == 0].reset_index(drop = True)
Cluster_1 = venues[venues['Cluster Labels'] == 1].reset_index(drop = True)
Cluster_2 = venues[venues['Cluster Labels'] == 2].reset_index(drop = True)
Cluster_3 = venues[venues['Cluster Labels'] == 3].reset_index(drop = True)
Cluster_4 = venues[venues['Cluster Labels'] == 4].reset_index(drop = True)

# %% [markdown]
# ### Let's Visualise the different venues in different Clusters

# %%
plt.figure(1,figsize=(20,10))

plt.subplots_adjust(hspace=0.5, wspace=0.7)

a = plt.subplot(221)
a.set_title('Cluster_0')
sns.countplot(Cluster_0['Category'])
plt.xticks(rotation=90)

a = plt.subplot(222)
a.set_title('Cluster_2')
sns.countplot(Cluster_2['Category'])
plt.xticks(rotation=90)

a = plt.subplot(223)
a.set_title('Cluster_3')
sns.countplot(Cluster_3['Category'])
plt.xticks(rotation=90)

a = plt.subplot(224)
a.set_title('Cluster_4')
sns.countplot(Cluster_4['Category'])

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Since **Cluster 1** has more venues so the plot is plotted seperately.

# %%
plt.figure(figsize = (10,5))
plt.title('Cluster_1')
sns.countplot(Cluster_1['Category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Above plots concludes that **Cluster 1** has maximum number of venues preceded by **Cluster 0**.

# %%
Cluster_0
# Out:
#                           VenueName  \
# 0                 Coffee Day Square
# 1                Cafe Coffee Day HQ
# 2      JW Marriott Executive Lounge
# 3       JW Marriott Hotel Bengaluru
# 4                BBC by JW Marriott
# 5                         INFOSYS 3
# 6                              Alba
# 7                         J W Salon
# 8                          HDFC Ltd
# 9                     Spice Terrace
# 10                              JLL
# 11                      J W Kitchen
# 12          Indian Institute Of Ham
# 13  The Spa @ JW Marriott Bengaluru
# 122         Indian Restaurant           Restaurant               1
# 123            Clothing Store       Clothing Store               1
# 124                    Office               Office               1
# 125       Leather Goods Store  Leather Goods Store               1
# 126              Neighborhood         Neighborhood               1
# 127                 Piano Bar            Piano Bar               1
# 128              Tech Startup         Tech Startup               1
# 129                     Diner                Diner               1
# 130                    Office               Office               1
# 131        Salon / Barbershop   Salon / Barbershop               1
#
# [132 rows x 7 columns]

# %%
Cluster_2
# Out:
#                                   VenueName             Address   Latitude  \
# 0                 Kanteerava Indoor Stadium  Corporation Circle  12.969619
# 1                   Sree Kanteerava Stadium               India  12.969581
# 2              st joseph Indian High school               India  12.970782
# 3            St joseph's indian high school           Bangalore  12.970610
# 4                St.Joseph's School Grounds  Virtual Mallya Rd.  12.970507
# 5  St. Joseph's Indian Composite PU College               India  12.970282
# 6            st.josephs indian institutions  Vittal Mallya Road  12.970948
# 7                        Nilgiris Cake Show    Vittal Mallya Rd  12.970560
# 8                 Vittal Mallya Rd Bus Stop    Vittal Mallya Rd  12.969631
#
#    Longitude                   SubCategory                      Category  \
# 0  77.593861                       Stadium                       Stadium
# 1  77.593107                       Stadium                       Stadium
# 2  77.595155            College Auditorium            College Auditorium
# 3  77.594690                   High School                   High School
# 4  77.594942                        School                        School
# 5  77.594674  General College & University  General College & University
# 6  77.594825            College Auditorium            College Auditorium
# 7  77.595239         General Entertainment         General Entertainment
# 8  77.594730                      Bus Line                      Bus Line
#
#    Cluster Labels
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# 5               2
# 6               2
# 7               2
# 8               2

# %%
Cluster_3
# Out:
#      VenueName   Address   Latitude  Longitude SubCategory Category  \
# 0  Cubbon Park  M G Road  12.977042  77.595277        Park     Park
#
#    Cluster Labels
# 0               3

# %%
Cluster_4
# Out:
#    VenueName    Address   Latitude  Longitude SubCategory Category  \
# 0  Bangalore  Karnātaka  12.972938  77.604415        City     City
#
#    Cluster Labels
# 0               4

# %% [markdown]
# ### An individual who has considerable amount of time shoud visit location under <span style='color:blue'> Cluster 1.</span>

# %% [markdown]
# <h1 style="color:red">Results and Discussion:</h1>

# %% [markdown]
# <ul>
# <li>Through the analysis done in the notebook we can that <span style='color:red'> <b>recommended_Cluster_2</b></span> contains the popular location to visit when on a strict schedule whereas <span style='color:red'> <b>Cluster_1</b></span> lists the best places to be visited when one has ample amount of time to explore Bangalore.</li>
#     <li>Due the difference in the number of places in <span style='color:red'> <b>recommended</b></span> and <span style='color:red'> <b>venues</b></span> data cluster number differ for same location in certain cases.</li>
# </ul>

# %% [markdown]
# <h1 style="color:red">Conclusion:</h1>

# %% [markdown]
# Purpose of this project was to identify Bangalore venues in order to aid travellers in narrowing down the search for location to be visited. By fetching data from Foursquare API we have first identified Recommended Venues that were rated by previous visitors. Clustering of those locations was then performed in order to create major venues of interest (containing greater number of different category locations) and table of those venues were created to be used as reference for final exploration by Travellers.
#
# Final decision on optimal visiting location will be made by visitors based on specific characteristics of neighbourhoods and locations in every cluster, taking into consideration additional factors like attractiveness of each location levels of noise / proximity to major roads, real estate availability, prices, social and economic dynamics of every neighbourhood etc.
