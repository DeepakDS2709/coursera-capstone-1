# %% [markdown]
# # IBM Data Science Capstone

# %% [markdown]
# ### Initially we will import all the required modules

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %% [markdown]
# #### Using requests module we will scrape the following link:
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M <br>
# After that we will fetch only the data.

# %%
data = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %% [markdown]
# #### Using BeautifulSoup I have processed the html data which has been stored in soup variable.

# %%
soup = BeautifulSoup(data,'lxml')

# %% [markdown]
# #### Below we have use find function to find the table tag
# And Then we have use <b>read_html</b> function to read the html table into Dataframe<br>
# Since the function returns a list therefore we have taken the first table from the list.

# %%
table = soup.find('table')
df = pd.read_html(str(table))
df = df[0]
df = df.rename(columns=df.iloc[0]).drop(df.index[0])
print(df.shape)
df.head(10)
# Out:
# (288, 3)
#    Postcode           Borough     Neighbourhood
# 1       M1A      Not assigned      Not assigned
# 2       M2A      Not assigned      Not assigned
# 3       M3A        North York         Parkwoods
# 4       M4A        North York  Victoria Village
# 5       M5A  Downtown Toronto      Harbourfront
# 6       M5A  Downtown Toronto       Regent Park
# 7       M6A        North York  Lawrence Heights
# 8       M6A        North York    Lawrence Manor
# 9       M7A      Queen's Park      Not assigned
# 10      M8A      Not assigned      Not assigned

# %% [markdown]
# #### All the rows where Borough is  Not Assigned have been droped.
# #### Futhermore the Not Assigned value have been replaced with the Borough value respectively

# %%
df = df.replace('Not assigned',np.nan)
df.dropna(subset = ['Borough'],inplace=True)
df['Neighbourhood'] = df['Neighbourhood'].fillna(df['Borough'])
df.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 3       M3A        North York         Parkwoods
# 4       M4A        North York  Victoria Village
# 5       M5A  Downtown Toronto      Harbourfront
# 6       M5A  Downtown Toronto       Regent Park
# 7       M6A        North York  Lawrence Heights
# 8       M6A        North York    Lawrence Manor
# 9       M7A      Queen's Park      Queen's Park
# 11      M9A         Etobicoke  Islington Avenue
# 12      M1B       Scarborough             Rouge
# 13      M1B       Scarborough           Malvern

# %%
df.shape
# Out:
# (211, 3)

# %% [markdown]
# ### Since we need Latitude and Longitude for respective postal code so we will be joining two Dataframes

# %%
lat = pd.read_csv('Geospatial_Coordinates.csv')
lat.rename(columns={'Postal Code': 'Postcode'}, inplace=True)
lat.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %% [markdown]
# #### Resultant DataFrame

# %%
result = pd.merge(df, lat,on = 'Postcode')
result.head()
# Out:
#   Postcode           Borough     Neighbourhood   Latitude  Longitude
# 0      M3A        North York         Parkwoods  43.753259 -79.329656
# 1      M4A        North York  Victoria Village  43.725882 -79.315572
# 2      M5A  Downtown Toronto      Harbourfront  43.654260 -79.360636
# 3      M5A  Downtown Toronto       Regent Park  43.654260 -79.360636
# 4      M6A        North York  Lawrence Heights  43.718518 -79.464763

# %% [markdown]
# ### We are filtering the data to get the data of Toronto city only

# %%
toronto_data = result[result['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
toronto_data.head()
# Out:
#   Postcode           Borough    Neighbourhood   Latitude  Longitude
# 0      M5A  Downtown Toronto     Harbourfront  43.654260 -79.360636
# 1      M5A  Downtown Toronto      Regent Park  43.654260 -79.360636
# 2      M5B  Downtown Toronto          Ryerson  43.657162 -79.378937
# 3      M5B  Downtown Toronto  Garden District  43.657162 -79.378937
# 4      M5C  Downtown Toronto   St. James Town  43.651494 -79.375418

# %% [markdown]
# ## Now is the time to make the clusters

# %% [markdown]
# ### I am going to cluster the data on the basis of number of Restraunt in the respective Area.
# #### Now to get the data of all the restraunts in the toronto I will be using FourSquare Api

# %%
CLIENT_ID = '00IVVZKELM2KPVHLPFMUXMY5QZHDGZPX5SSB4HURZJ2KKKMT' # your Foursquare ID
CLIENT_SECRET = 'ZZQNWZTOEZSYA2MXCQBU12OIELDNEQQH3YKKJBDNIWYZ0ZF4' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
#Max number of venues within radius
LIMIT = 100
radius=500
def getRestaurant(names, latitudes, longitudes, category):
    
    Restaurant_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius,
            category,
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['venues']

        # return only relevant information for each nearby venue
        Restaurant_list.append([(
            name, 
            lat, 
            lng, 
            v['name'], 
            v['location']['lat'], 
            v['location']['lng'],  
            v['categories'][0]['name']) for v in results])
        

    nearby_Restaurant = pd.DataFrame([item for Restaurant in Restaurant_list for item in Restaurant])
    nearby_Restaurant.columns = ['Postal Code', 
                  'Postal Code Latitude', 
                  'Postal Code Longitude', 
                  'Venue', 
                  'Restaurant Latitude', 
                  'Restaurant Longitude', 
                  'Category']
    return(nearby_Restaurant)

Restaurant = '4bf58dd8d48988d1c4941735'#category code for cafe

toronto_Restaurants = getRestaurant(names=toronto_data['Postcode'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude'],
                                   category=Restaurant
                                  )

# %%
toronto_Restaurants.head(20)
# Out:
#    Postal Code  Postal Code Latitude  Postal Code Longitude  \
# 0          M5A             43.654260             -79.360636
# 1          M5A             43.654260             -79.360636
# 2          M5A             43.654260             -79.360636
# 3          M5A             43.654260             -79.360636
# 4          M5A             43.654260             -79.360636
# 5          M5A             43.654260             -79.360636
# 6          M5A             43.654260             -79.360636
# 7          M5A             43.654260             -79.360636
# 8          M5A             43.654260             -79.360636
# 9          M5A             43.654260             -79.360636
# 10         M5A             43.654260             -79.360636
# 11         M5A             43.654260             -79.360636
# 12         M5A             43.654260             -79.360636
# 13         M5A             43.654260             -79.360636
# 14         M5B             43.657162             -79.378937
# 15         M5B             43.657162             -79.378937
# 16         M5B             43.657162             -79.378937
# 17         M5B             43.657162             -79.378937
# 18         M5B             43.657162             -79.378937
# 19         M5B             43.657162             -79.378937
#
#                        Venue  Restaurant Latitude  Restaurant Longitude  \
# 0   Dominion Pub and Kitchen            43.656919            -79.358967
# 1             Impact Kitchen            43.656369            -79.356980
# 2                Flame Shack            43.656844            -79.358917
# 3      The Cannery - Bldg 58            43.649952            -79.359086
# 4               Mom and Pops            43.649980            -79.363883
# 5        Pure Pizza & Burger            43.659454            -79.366029
# 6                Beyond Food            43.653094            -79.365379
# 7   Dominion Pub and Kitchen            43.656919            -79.358967
# 8             Impact Kitchen            43.656369            -79.356980
# 9                Flame Shack            43.656844            -79.358917
# 10     The Cannery - Bldg 58            43.649952            -79.359086
# 11              Mom and Pops            43.649980            -79.363883
# 12       Pure Pizza & Burger            43.659454            -79.366029
# 13               Beyond Food            43.653094            -79.365379
# 14  Jack Astor's Bar & Grill            43.656019            -79.380326
# 15         The Pickle Barrel            43.656412            -79.381718
# 16    Eaton Centre Top Patio            43.656571            -79.382354
# 17         JOEY Eaton Centre            43.655404            -79.381929
# 18                       KFC            43.655100            -79.380781
# 19          Big Smoke Burger            43.654907            -79.380873
#
#                 Category
# 0                    Pub
# 1             Restaurant
# 2             Restaurant
# 3             Restaurant
# 4             Restaurant
# 5             Restaurant
# 6             Restaurant
# 7                    Pub
# 8             Restaurant
# 9             Restaurant
# 10            Restaurant
# 11            Restaurant
# 12            Restaurant
# 13            Restaurant
# 14            Restaurant
# 15            Restaurant
# 16            Restaurant
# 17            Restaurant
# 18  Fast Food Restaurant
# 19            Restaurant

# %%
toronto_Restaurants = toronto_Restaurants.groupby(['Postal Code']).size().reset_index(name='Restaurants')

#Add in neighborhood names for convenience
toronto_Restaurants = toronto_Restaurants.set_index('Postal Code').join(result.set_index('Postcode'))
# toronto_Restaurants.reset_index(inplace=True)
toronto_Restaurants
# Out:
#      Restaurants           Borough                    Neighbourhood  \
# M4X           12  Downtown Toronto                      Cabbagetown
# M4X           12  Downtown Toronto                   St. James Town
# M4Y           24  Downtown Toronto             Church and Wellesley
# M5A           14  Downtown Toronto                     Harbourfront
# M5A           14  Downtown Toronto                      Regent Park
# M5B           74  Downtown Toronto                          Ryerson
# M5B           74  Downtown Toronto                  Garden District
# M5C           44  Downtown Toronto                   St. James Town
# M5E           29  Downtown Toronto                      Berczy Park
# M5G           34  Downtown Toronto               Central Bay Street
# M5H          147  Downtown Toronto                         Adelaide
# M5H          147  Downtown Toronto                             King
# M5H          147  Downtown Toronto                         Richmond
# M5J           87  Downtown Toronto                Harbourfront East
# M5J           87  Downtown Toronto                  Toronto Islands
# M5J           87  Downtown Toronto                    Union Station
# M5K           98  Downtown Toronto                  Design Exchange
# M5K           98  Downtown Toronto          Toronto Dominion Centre
# M5L           98  Downtown Toronto                   Commerce Court
# M5L           98  Downtown Toronto                   Victoria Hotel
# M5S           18  Downtown Toronto                          Harbord
# M5S           18  Downtown Toronto            University of Toronto
# M5T           48  Downtown Toronto                        Chinatown
# M5T           48  Downtown Toronto                      Grange Park
# M5T           48  Downtown Toronto                Kensington Market
# M5W           44  Downtown Toronto  Stn A PO Boxes 25 The Esplanade
# M5X           98  Downtown Toronto             First Canadian Place
# M5X           98  Downtown Toronto                 Underground city
# M6G            3  Downtown Toronto                         Christie
#
#       Latitude  Longitude
# M4X  43.667967 -79.367675
# M4X  43.667967 -79.367675
# M4Y  43.665860 -79.383160
# M5A  43.654260 -79.360636
# M5A  43.654260 -79.360636
# M5B  43.657162 -79.378937
# M5B  43.657162 -79.378937
# M5C  43.651494 -79.375418
# M5E  43.644771 -79.373306
# M5G  43.657952 -79.387383
# M5H  43.650571 -79.384568
# M5H  43.650571 -79.384568
# M5H  43.650571 -79.384568
# M5J  43.640816 -79.381752
# M5J  43.640816 -79.381752
# M5J  43.640816 -79.381752
# M5K  43.647177 -79.381576
# M5K  43.647177 -79.381576
# M5L  43.648198 -79.379817
# M5L  43.648198 -79.379817
# M5S  43.662696 -79.400049
# M5S  43.662696 -79.400049
# M5T  43.653206 -79.400049
# M5T  43.653206 -79.400049
# M5T  43.653206 -79.400049
# M5W  43.646435 -79.374846
# M5X  43.648429 -79.382280
# M5X  43.648429 -79.382280
# M6G  43.669542 -79.422564

# %%
# set number of clusters
kclusters = 5

manhattan_grouped_clustering = toronto_Restaurants[['Latitude','Longitude']]

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(manhattan_grouped_clustering)

# check cluster labels generated for each row in the dataframe
toronto_Restaurants['Cluster Labels'] = kmeans.labels_

# %%
toronto_rest
# Out:
#    index  Restaurants           Borough                    Neighbourhood  \
# 0    M4X           12  Downtown Toronto                      Cabbagetown
# 1    M4X           12  Downtown Toronto                   St. James Town
# 2    M4Y           24  Downtown Toronto             Church and Wellesley
# 3    M5A           14  Downtown Toronto                     Harbourfront
# 4    M5A           14  Downtown Toronto                      Regent Park
# 5    M5B           74  Downtown Toronto                          Ryerson
# 6    M5B           74  Downtown Toronto                  Garden District
# 7    M5C           44  Downtown Toronto                   St. James Town
# 8    M5E           29  Downtown Toronto                      Berczy Park
# 9    M5G           34  Downtown Toronto               Central Bay Street
# 10   M5H          147  Downtown Toronto                         Adelaide
# 11   M5H          147  Downtown Toronto                             King
# 12   M5H          147  Downtown Toronto                         Richmond
# 13   M5J           87  Downtown Toronto                Harbourfront East
# 14   M5J           87  Downtown Toronto                  Toronto Islands
# 15   M5J           87  Downtown Toronto                    Union Station
# 16   M5K           98  Downtown Toronto                  Design Exchange
# 17   M5K           98  Downtown Toronto          Toronto Dominion Centre
# 18   M5L           98  Downtown Toronto                   Commerce Court
# 19   M5L           98  Downtown Toronto                   Victoria Hotel
# 20   M5S           18  Downtown Toronto                          Harbord
# 21   M5S           18  Downtown Toronto            University of Toronto
# 22   M5T           48  Downtown Toronto                        Chinatown
# 23   M5T           48  Downtown Toronto                      Grange Park
# 24   M5T           48  Downtown Toronto                Kensington Market
# 25   M5W           44  Downtown Toronto  Stn A PO Boxes 25 The Esplanade
# 26   M5X           98  Downtown Toronto             First Canadian Place
# 27   M5X           98  Downtown Toronto                 Underground city
# 28   M6G            3  Downtown Toronto                         Christie
#
#      Latitude  Longitude  Cluster Labels
# 0   43.667967 -79.367675               4
# 1   43.667967 -79.367675               4
# 2   43.665860 -79.383160               3
# 3   43.654260 -79.360636               4
# 4   43.654260 -79.360636               4
# 5   43.657162 -79.378937               3
# 6   43.657162 -79.378937               3
# 7   43.651494 -79.375418               0
# 8   43.644771 -79.373306               0
# 9   43.657952 -79.387383               3
# 10  43.650571 -79.384568               0
# 11  43.650571 -79.384568               0
# 12  43.650571 -79.384568               0
# 13  43.640816 -79.381752               0
# 14  43.640816 -79.381752               0
# 15  43.640816 -79.381752               0
# 16  43.647177 -79.381576               0
# 17  43.647177 -79.381576               0
# 18  43.648198 -79.379817               0
# 19  43.648198 -79.379817               0
# 20  43.662696 -79.400049               2
# 21  43.662696 -79.400049               2
# 22  43.653206 -79.400049               2
# 23  43.653206 -79.400049               2
# 24  43.653206 -79.400049               2
# 25  43.646435 -79.374846               0
# 26  43.648429 -79.382280               0
# 27  43.648429 -79.382280               0
# 28  43.669542 -79.422564               1
